# %%
import numpy as np
import skfuzzy as fuzz
from skfuzzy import control as ctrl


weight = ctrl.Antecedent(np.arange(0, 23.4, 1.8), 'INPUT weight') #start=0 ,stop=21,step=1
amount = ctrl.Antecedent(np.arange(0, 1.768, 0.136), 'INPUT amount')
speed = ctrl.Consequent(np.arange(0, 11.7 , 0.9), 'OUTPUT speed')
# print(weight)

#แบ่งขนาด weight = 10
weight['1'] = fuzz.trimf(weight.universe, [0, 1.8, 3.6])
weight['2'] = fuzz.trimf(weight.universe, [1.8, 3.6, 5.4])
weight['3'] = fuzz.trimf(weight.universe, [3.6, 5.4, 7.2])
weight['4'] = fuzz.trimf(weight.universe, [5.4, 7.2, 9])
weight['5'] = fuzz.trimf(weight.universe, [7.2, 9, 10.8])
weight['6'] = fuzz.trimf(weight.universe, [9, 10.8, 12.6])
weight['7'] = fuzz.trimf(weight.universe, [10.8, 12.6, 14.4])
weight['8'] = fuzz.trimf(weight.universe, [12.6, 14.4, 16.2])
weight['9'] = fuzz.trimf(weight.universe, [14.4, 16.2, 18])
weight['10'] = fuzz.trimf(weight.universe, [16.2, 18, 19.8])

#แบ่งขนาด amount = 10
amount['1'] = fuzz.trimf(amount.universe, [0, 0.136, 0.272])
amount['2'] = fuzz.trimf(amount.universe, [0.136, 0.272, 0.408])
amount['3'] = fuzz.trimf(amount.universe, [0.272, 0.408, 0.544])
amount['4'] = fuzz.trimf(amount.universe, [0.408, 0.544, 0.68])
amount['5'] = fuzz.trimf(amount.universe, [0.544, 0.68, 0.816])
amount['6'] = fuzz.trimf(amount.universe, [0.68, 0.816, 0.952])
amount['7'] = fuzz.trimf(amount.universe, [0.816, 0.952, 1.088])
amount['8'] = fuzz.trimf(amount.universe, [0.952, 1.088, 1.224])
amount['9'] = fuzz.trimf(amount.universe, [1.088, 1.224, 1.36])
amount['10'] = fuzz.trimf(amount.universe, [1.224, 1.36, 1.496])

#แบ่งขนาด speed = 10
speed['1'] = fuzz.trimf(speed.universe, [0, 0.9, 1.8])
speed['2'] = fuzz.trimf(speed.universe, [0.9, 1.8, 2.7])
speed['3'] = fuzz.trimf(speed.universe, [1.8, 2.7, 3.6])
speed['4'] = fuzz.trimf(speed.universe, [2.7, 3.6, 4.5])
speed['5'] = fuzz.trimf(speed.universe, [3.6, 4.5 , 5.4])
speed['6'] = fuzz.trimf(speed.universe, [4.5, 5.4, 6.3])
speed['7'] = fuzz.trimf(speed.universe, [5.4, 6.3, 7.2])
speed['8'] = fuzz.trimf(speed.universe, [6.3, 7.2, 8.1])
speed['9'] = fuzz.trimf(speed.universe, [7.2, 8.1, 9.0])
speed['10'] = fuzz.trimf(speed.universe, [8.1, 9.0, 9.9])


# You can see how these look with .view()
weight.view()
amount.view()
speed.view()

# ถ้า weight+amount =20 or 19 speed =10
# ถ้า weight+amount =18 or 17 speed =9
# ถ้า weight+amount =16 or 15 speed =8
# ถ้า weight+amount =14 or 13 speed =7
# ถ้า weight+amount =12 or 11 speed =6
# ถ้า weight+amount =10 or 9 speed =5
# ถ้า weight+amount =8 or 7 speed =4
# ถ้า weight+amount =6 or 5 speed =3
# ถ้า weight+amount =4 or 3 speed =2
# ถ้า weight+amount =2 speed =1

rule1 = ctrl.Rule(weight['1'] & amount['1'], speed['1'])
rule2 = ctrl.Rule(weight['2'] & amount['1'], speed['2'])
rule3 = ctrl.Rule(weight['3'] & amount['1'], speed['2'])
rule4 = ctrl.Rule(weight['4'] & amount['1'], speed['3'])
rule5 = ctrl.Rule(weight['5'] & amount['1'], speed['3'])
rule6 = ctrl.Rule(weight['6'] & amount['1'], speed['4'])
rule7 = ctrl.Rule(weight['7'] & amount['1'], speed['4'])
rule8 = ctrl.Rule(weight['8'] & amount['1'], speed['5'])
rule9 = ctrl.Rule(weight['9'] & amount['1'], speed['5'])
rule10 = ctrl.Rule(weight['10'] & amount['1'], speed['6'])

rule11 = ctrl.Rule(weight['1'] & amount['2'], speed['2'])
rule12 = ctrl.Rule(weight['2'] & amount['2'], speed['2'])
rule13 = ctrl.Rule(weight['3'] & amount['2'], speed['3'])
rule14 = ctrl.Rule(weight['4'] & amount['2'], speed['3'])
rule15 = ctrl.Rule(weight['5'] & amount['2'], speed['4'])
rule16 = ctrl.Rule(weight['6'] & amount['2'], speed['4'])
rule17 = ctrl.Rule(weight['7'] & amount['2'], speed['5'])
rule18 = ctrl.Rule(weight['8'] & amount['2'], speed['5'])
rule19 = ctrl.Rule(weight['9'] & amount['2'], speed['6'])
rule20 = ctrl.Rule(weight['10'] & amount['2'], speed['6'])

rule21 = ctrl.Rule(weight['1'] & amount['3'], speed['2'])
rule22 = ctrl.Rule(weight['2'] & amount['3'], speed['3'])
rule23 = ctrl.Rule(weight['3'] & amount['3'], speed['3'])
rule24 = ctrl.Rule(weight['4'] & amount['3'], speed['4'])
rule25 = ctrl.Rule(weight['5'] & amount['3'], speed['4'])
rule26 = ctrl.Rule(weight['6'] & amount['3'], speed['5'])
rule27 = ctrl.Rule(weight['7'] & amount['3'], speed['5'])
rule28 = ctrl.Rule(weight['8'] & amount['3'], speed['6'])
rule29 = ctrl.Rule(weight['9'] & amount['3'], speed['6'])
rule30 = ctrl.Rule(weight['10'] & amount['3'], speed['7'])

rule31 = ctrl.Rule(weight['1'] & amount['4'], speed['3'])
rule32 = ctrl.Rule(weight['2'] & amount['4'], speed['3'])
rule33 = ctrl.Rule(weight['3'] & amount['4'], speed['4'])
rule34 = ctrl.Rule(weight['4'] & amount['4'], speed['4'])
rule35 = ctrl.Rule(weight['5'] & amount['4'], speed['5'])
rule36 = ctrl.Rule(weight['6'] & amount['4'], speed['5'])
rule37 = ctrl.Rule(weight['7'] & amount['4'], speed['6'])
rule38 = ctrl.Rule(weight['8'] & amount['4'], speed['6'])
rule39 = ctrl.Rule(weight['9'] & amount['4'], speed['7'])
rule40 = ctrl.Rule(weight['10'] & amount['4'], speed['7'])

rule41 = ctrl.Rule(weight['1'] & amount['5'], speed['3'])
rule42 = ctrl.Rule(weight['2'] & amount['5'], speed['4'])
rule43 = ctrl.Rule(weight['3'] & amount['5'], speed['4'])
rule44 = ctrl.Rule(weight['4'] & amount['5'], speed['5'])
rule45 = ctrl.Rule(weight['5'] & amount['5'], speed['5'])
rule46 = ctrl.Rule(weight['6'] & amount['5'], speed['6'])
rule47 = ctrl.Rule(weight['7'] & amount['5'], speed['6'])
rule48 = ctrl.Rule(weight['8'] & amount['5'], speed['7'])
rule49 = ctrl.Rule(weight['9'] & amount['5'], speed['7'])
rule50 = ctrl.Rule(weight['10'] & amount['5'], speed['8'])

rule51 = ctrl.Rule(weight['1'] & amount['6'], speed['4'])
rule52 = ctrl.Rule(weight['2'] & amount['6'], speed['4'])
rule53 = ctrl.Rule(weight['3'] & amount['6'], speed['5'])
rule54 = ctrl.Rule(weight['4'] & amount['6'], speed['5'])
rule55 = ctrl.Rule(weight['5'] & amount['6'], speed['6'])
rule56 = ctrl.Rule(weight['6'] & amount['6'], speed['6'])
rule57 = ctrl.Rule(weight['7'] & amount['6'], speed['7'])
rule58 = ctrl.Rule(weight['8'] & amount['6'], speed['7'])
rule59 = ctrl.Rule(weight['9'] & amount['6'], speed['8'])
rule60 = ctrl.Rule(weight['10'] & amount['6'], speed['8'])

rule61 = ctrl.Rule(weight['1'] & amount['7'], speed['4'])
rule62 = ctrl.Rule(weight['2'] & amount['7'], speed['5'])
rule63 = ctrl.Rule(weight['3'] & amount['7'], speed['5'])
rule64 = ctrl.Rule(weight['4'] & amount['7'], speed['6'])
rule65 = ctrl.Rule(weight['5'] & amount['7'], speed['6'])
rule66 = ctrl.Rule(weight['6'] & amount['7'], speed['7'])
rule67 = ctrl.Rule(weight['7'] & amount['7'], speed['7'])
rule68 = ctrl.Rule(weight['8'] & amount['7'], speed['8'])
rule69 = ctrl.Rule(weight['9'] & amount['7'], speed['8'])
rule70 = ctrl.Rule(weight['10'] & amount['7'], speed['9'])

rule71 = ctrl.Rule(weight['1'] & amount['8'], speed['5'])
rule72 = ctrl.Rule(weight['2'] & amount['8'], speed['5'])
rule73 = ctrl.Rule(weight['3'] & amount['8'], speed['6'])
rule74 = ctrl.Rule(weight['4'] & amount['8'], speed['6'])
rule75 = ctrl.Rule(weight['5'] & amount['8'], speed['7'])
rule76 = ctrl.Rule(weight['6'] & amount['8'], speed['7'])
rule77 = ctrl.Rule(weight['7'] & amount['8'], speed['8'])
rule78 = ctrl.Rule(weight['8'] & amount['8'], speed['8'])
rule79 = ctrl.Rule(weight['9'] & amount['8'], speed['9'])
rule80 = ctrl.Rule(weight['10'] & amount['8'], speed['9'])

rule81 = ctrl.Rule(weight['1'] & amount['9'], speed['5'])
rule82 = ctrl.Rule(weight['2'] & amount['9'], speed['6'])
rule83 = ctrl.Rule(weight['3'] & amount['9'], speed['6'])
rule84 = ctrl.Rule(weight['4'] & amount['9'], speed['7'])
rule85 = ctrl.Rule(weight['5'] & amount['9'], speed['7'])
rule86 = ctrl.Rule(weight['6'] & amount['9'], speed['8'])
rule87 = ctrl.Rule(weight['7'] & amount['9'], speed['8'])
rule88 = ctrl.Rule(weight['8'] & amount['9'], speed['9'])
rule89 = ctrl.Rule(weight['9'] & amount['9'], speed['9'])
rule90 = ctrl.Rule(weight['10'] & amount['9'], speed['10'])

rule91 = ctrl.Rule(weight['1'] & amount['10'], speed['6'])
rule92 = ctrl.Rule(weight['2'] & amount['10'], speed['6'])
rule93 = ctrl.Rule(weight['3'] & amount['10'], speed['7'])
rule94 = ctrl.Rule(weight['4'] & amount['10'], speed['7'])
rule95 = ctrl.Rule(weight['5'] & amount['10'], speed['8'])
rule96 = ctrl.Rule(weight['6'] & amount['10'], speed['8'])
rule97 = ctrl.Rule(weight['7'] & amount['10'], speed['9'])
rule98 = ctrl.Rule(weight['8'] & amount['10'], speed['9'])
rule99 = ctrl.Rule(weight['9'] & amount['10'], speed['10'])
rule100 = ctrl.Rule(weight['10'] & amount['10'], speed['10'])



rule1.view()
speedping_ctrl = ctrl.ControlSystem(
    [rule1, rule2, rule3, rule4, rule5, rule6, rule7, rule8, rule9,rule10, rule11, rule12, rule13, rule14, rule15, rule16, rule17,
     rule18, rule19, rule20, rule21, rule22, rule23, rule24, rule25, rule26, rule27, rule28, rule29, rule30, rule31, rule32, 
     rule33, rule34, rule35, rule36,rule37, rule38, rule39, rule40,rule41, rule42, rule43, rule44, rule45, rule46, rule47,
     rule48, rule49,rule50,rule51, rule52, rule53, rule54, rule55, rule56, rule57, rule58, rule59,rule60,rule61, rule62,
     rule63, rule64, rule65, rule66, rule67, rule68, rule69,rule70, rule71, rule72, rule73, rule74, rule75, rule76, rule77, 
     rule78, rule79,rule80,rule81, rule82, rule83, rule84, rule85, rule86, rule87, rule88, rule89,rule90,rule91, rule92,
     rule93, rule94, rule95, rule96, rule97, rule98, rule99,rule100
    ])
speedping = ctrl.ControlSystemSimulation(speedping_ctrl)
# Pass inputs to the ControlSystem using Antecedent labels with Pythonic API
# Note: if you like passing many inputs all at once, use .inputs(dict_of_data)
speedping.input['INPUT weight'] = 13
speedping.input['INPUT amount'] = 0.9

# Crunch the numbers
speedping.compute()
speed.view(sim=speedping)
print("ความเร็วของการหมุนมอเตอร์ที่เหมาะสมต่อการซักผ้า คือ :",speedping.output['OUTPUT speed'])
###
# Out:
# C:\Users\kedgo\anaconda3\lib\site-packages\skfuzzy\control\fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# C:\Users\kedgo\anaconda3\lib\site-packages\skfuzzy\control\fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# C:\Users\kedgo\anaconda3\lib\site-packages\skfuzzy\control\fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# C:\Users\kedgo\anaconda3\lib\site-packages\skfuzzy\control\fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# ...
